# %% [markdown]
# Este no lo he estudiado, idk de donde salió pero lo dejaré para tener modelos de prueba por el momento.

# %%
# Manejo de datos
import numpy as np
import pandas as pd
import os
from datetime import datetime

# Gráficos
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['font.size'] = 10

# Preprocesado y modelado
import sklearn
import catboost
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import joblib
import itertools
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

# Configuración warnings (Quitar en caso de errores desconocidos)
import warnings
warnings.filterwarnings('ignore')

# Versión de paquetes usados
color = '\033[1m\033[38;5;208m'
print(f"{color}Versión de las librerias utilizadas:")
print(f"{color}- Version sklearn: {sklearn.__version__}")
print(f"{color}- Version catboost: {catboost.__version__}")
print(f"{color}- Version pandas: {pd.__version__}")
print(f"{color}- Version numpy: {np.__version__}")
# Out:
# Versión de las librerias utilizadas:
# - Version sklearn: 1.7.2
# - Version catboost: 1.2.8
# - Version pandas: 2.3.3
# - Version numpy: 2.2.6

# %%
try:
    df = pd.read_csv("../Datasets/accesos_biblioteca.csv")
    print("Dataset cargado desde 'Datasets/accesos_biblioteca.csv'")
except FileNotFoundError:
    print("ERROR: No se encontró el archivo 'accesos_biblioteca.csv'.")
    exit(1)
# Out:
# Dataset cargado desde 'Datasets/accesos_biblioteca.csv'

# %%
print("Dataset original - Columnas iniciales:")
print(f"Columnas: {list(df.columns)}")
print(f"Forma del dataset: {df.shape}")
print("\nPrimeras 3 filas:")
print(df.head(3))
# Out:
# Dataset original - Columnas iniciales:
# Columnas: ['Fecha', 'Día', 'Mes', 'Año', 'Semestre', 'Accesos', 'Vacaciones?']
# Forma del dataset: (511, 7)
#
# Primeras 3 filas:
#         Fecha  Día  Mes   Año  Semestre  Accesos  Vacaciones?
# 0  2023-12-14   14   12  2023         2      953            0
# 1  2023-12-15   15   12  2023         2      549            0
# 2  2023-12-16   16   12  2023         2       71            0

# %%
def agregar_lags(df, columna, lags):
    for lag in lags:
        df[f'lag_{lag}'] = df[columna].shift(lag)
    return df

def agregar_medias_moviles(df, columna, ventanas):
    for ventana in ventanas:
        df[f'media_movil_{ventana}'] = df[columna].shift(1).rolling(window=ventana, min_periods=1).mean()
    return df

def agregar_variables_ciclicas(df, columna_mes, columna_fecha):
    df['mes_sin'] = np.sin(2 * np.pi * df[columna_mes] / 12)
    df['mes_cos'] = np.cos(2 * np.pi * df[columna_mes] / 12)
    df['dia_semana_sin'] = np.sin(2 * np.pi * pd.to_datetime(df[columna_fecha]).dt.weekday / 7)
    df['dia_semana_cos'] = np.cos(2 * np.pi * pd.to_datetime(df[columna_fecha]).dt.weekday / 7)
    return df

def agregar_ewma(df, columna, spans):
    for span in spans:
        df[f'ewma_{span}'] = df[columna].shift(1).ewm(span=span, adjust=False).mean()
    return df

# %%
def obtener_semestre(mes):
    if 3 <= mes <= 7:
        return 1  # Primer semestre
    elif 8 <= mes <= 12:
        return 2  # Segundo semestre
    else:
        return 0  # Fuera de semestre (enero, febrero)
    
def obtener_semana_semestre(fecha):
    mes = fecha.month
    dia = fecha.day
    if 3 <= mes <= 7:
        inicio_semestre = datetime(fecha.year, 3, 1)
    elif 8 <= mes <= 12:
        inicio_semestre = datetime(fecha.year, 8, 1)
    else:
        return 0  # Fuera de semestre
    delta = fecha - inicio_semestre
    semana_semestre = delta.days // 7 + 1
    return semana_semestre

# %%
for col in ['Accesos']:
    df[col] = df[col].fillna(0).astype(int)

df = df[
    pd.to_datetime(df['Fecha']).dt.weekday != 6
].reset_index(drop=True)

df = agregar_medias_moviles(df, 'Accesos', [7, 14, 30])
df = agregar_variables_ciclicas(df, 'Mes', 'Fecha')
df = agregar_ewma(df, 'Accesos', [7, 14, 30])

df['Semestre'] = df['Mes'].apply(obtener_semestre)
df['Semana_Semestre'] = pd.to_datetime(df['Fecha']).apply(obtener_semana_semestre)

df['Fecha'] = pd.to_datetime(df['Fecha'])

df = agregar_lags(df, 'Accesos', [7, 14, 21])

df = df.dropna().reset_index(drop=True)
df.tail(5)
# Out:
#          Fecha  Día  Mes   Año  Semestre  Accesos  Vacaciones?  media_movil_7  \
# 412 2025-05-02    2    5  2025         1        0            1    1585.571429
# 413 2025-05-03    3    5  2025         1        0            1    1222.142857
# 414 2025-05-05    5    5  2025         1     2750            0    1028.428571
# 415 2025-05-06    6    5  2025         1     1866            0    1346.142857
# 416 2025-05-07    7    5  2025         1     2254            0    1269.857143
#
#      media_movil_14  media_movil_30  ...   mes_cos  dia_semana_sin  \
# 412     1941.642857     2525.500000  ... -0.866025       -0.433884
# 413     1645.571429     2445.066667  ... -0.866025       -0.974928
# 414     1531.857143     2438.466667  ... -0.866025        0.000000
# 415     1728.285714     2417.700000  ... -0.866025        0.781831
# 416     1861.571429     2362.766667  ... -0.866025        0.974928
#
#      dia_semana_cos       ewma_7      ewma_14      ewma_30  Semana_Semestre  \
# 412       -0.900969  1525.983140  1921.208321  2153.063866                9
# 413       -0.222521  1144.487355  1665.047212  2014.156520               10
# 414        1.000000   858.365516  1443.040917  1884.210938               10
# 415        0.623490  1331.274137  1617.302128  1940.068296               10
# 416       -0.222521  1464.955603  1650.461844  1935.289697               10
#
#       lag_7  lag_14  lag_21
# 412  2544.0  4145.0  3923.0
# 413  1356.0  1592.0  4248.0
# 414   526.0     0.0  3976.0
# 415  2400.0     0.0  3140.0
# 416  2568.0  3841.0   852.0
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Fecha'], df['Accesos'], linestyle='-', color='b', alpha=0.5)

# Puntos normales (no vacaciones ni sábados)
no_vac_no_sab = (df['Vacaciones?'] == 0) & (df['Fecha'].dt.weekday != 5)
plt.scatter(df['Fecha'][no_vac_no_sab], df['Accesos'][no_vac_no_sab], color='b', label='Día normal')

# Puntos de vacaciones
vac = (df['Vacaciones?'] == 1)
plt.scatter(df['Fecha'][vac], df['Accesos'][vac], color='r', label='Vacaciones?')

# Puntos de sábados
sab = (df['Vacaciones?'] == 0) & (df['Fecha'].dt.weekday == 5)
plt.scatter(df['Fecha'][sab], df['Accesos'][sab], color='g', label='Sábado')

plt.title('Accesos Diarios a la Universidad')
plt.xlabel('Fecha')
plt.ylabel('Número de Accesos')
plt.xticks(rotation=45)
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %%
X = df.drop(columns=['Fecha', 'Accesos'])
y = df['Accesos']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

print(f"Datos de entrenamiento: {len(X_train)}")
print(f"Datos de prueba: {len(X_test)}")
# Out:
# Datos de entrenamiento: 333
# Datos de prueba: 84

# %%
os.makedirs('../Archivos Auxiliares', exist_ok=True)
if "modelo_CatBoost.pkl" not in os.listdir('../Archivos Auxiliares'):
    print("Entrenando el modelo CatBoost")
    tscv = TimeSeriesSplit(n_splits=5)
    param_grid = {
        'iterations': [200, 400], 
        'learning_rate': [0.03, 0.08, 0.15], # Rango más amplio y fino
        'depth': [5, 7, 9], 
        'l2_leaf_reg': [1, 3, 5], 
        'min_data_in_leaf': [1, 5, 10], # NUEVO: Control de sobreajuste
        'subsample': [0.7, 0.9], # NUEVO: Muestreo de datos (robustez)
        # 'border_count': [128, 254], # Podrías probar más valores si el set es muy grande
    }

    grid_search = GridSearchCV(
        CatBoostRegressor(random_state=42, thread_count=-1, verbose=0, loss_function='RMSE'),
        param_grid,
        cv=tscv,
        scoring='neg_root_mean_squared_error',
        n_jobs=-1,
        verbose=1
    )

    grid_search.fit(X_train, y_train)

    print(f'\nMejores parámetros: {grid_search.best_params_}')

    best_params = grid_search.best_params_

    model = CatBoostRegressor(
        **best_params, 
        random_state=42, 
        thread_count=-1, 
        loss_function='RMSE',
    )

    model.fit(X_train, y_train)
    joblib.dump(model, '../Archivos Auxiliares/modelo_CatBoost.pkl')
    print("Modelo guardado como '../Archivos Auxiliares/modelo_CatBoost.pkl'")
else:
    model = joblib.load('../Archivos Auxiliares/modelo_CatBoost.pkl')
    print("Modelo CatBoost cargado desde '../Archivos Auxiliares/modelo_CatBoost.pkl'")
# Out:
# Modelo CatBoost cargado desde '../Archivos Auxiliares/modelo_CatBoost.pkl'

# %%
# Importancia de las características
importancias = model.feature_importances_
columnas_modelo = X.columns[:len(importancias)]
indices = np.argsort(importancias)[::-1]

print("\n Importancia de las características \n")
for i, idx in enumerate(indices):
    print(f"{i + 1:2d}. {columnas_modelo[idx]}: {importancias[idx]:.4f}")
# Out:
#  Importancia de las características
#
#  1. Vacaciones?: 32.7522
#  2. dia_semana_sin: 20.7574
#  3. ewma_30: 9.8723
#  4. ewma_7: 7.1465
#  5. ewma_14: 5.6226
#  6. Semana_Semestre: 5.3378
#  7. media_movil_7: 3.8793
#  8. mes_cos: 3.4913
#  9. media_movil_14: 2.5808
# 10. Mes: 1.3596
# 11. mes_sin: 1.3078
# 12. Día: 1.2192
# 13. dia_semana_cos: 1.2047
# 14. media_movil_30: 0.9796
# 15. lag_7: 0.8921
# 16. lag_14: 0.6691
# 17. lag_21: 0.5461
# 18. Semestre: 0.3818
# 19. Año: 0.0000

# %%
# Eliminar características con importancia menor a 0.01
umbral_importancia = 0.01

# Solo considera las columnas usadas por el modelo
columnas_modelo = X.columns[:len(importancias)]
caracteristicas_seleccionadas = [col for col, imp in zip(columnas_modelo, importancias) if imp >= umbral_importancia]

X_train = X_train[caracteristicas_seleccionadas]
X_test = X_test[caracteristicas_seleccionadas]

# Reentrenar el modelo con las características seleccionadas
model.fit(X_train, y_train)
# Out:
# 0:	learn: 1227.6586153	total: 118ms	remaining: 23.5s
# 1:	learn: 1103.9059931	total: 120ms	remaining: 11.8s
# 2:	learn: 1015.2263624	total: 121ms	remaining: 7.97s
# 3:	learn: 923.7289237	total: 123ms	remaining: 6.02s
# 4:	learn: 843.6140984	total: 124ms	remaining: 4.85s
# 5:	learn: 768.6366759	total: 125ms	remaining: 4.05s
# 6:	learn: 715.0400025	total: 126ms	remaining: 3.48s
# 7:	learn: 674.8197006	total: 127ms	remaining: 3.06s
# 8:	learn: 633.6031635	total: 128ms	remaining: 2.72s
# 9:	learn: 582.5495647	total: 129ms	remaining: 2.46s
# 10:	learn: 553.4186056	total: 130ms	remaining: 2.24s
# 11:	learn: 515.5676661	total: 132ms	remaining: 2.06s
# 12:	learn: 494.0383353	total: 133ms	remaining: 1.91s
# 13:	learn: 472.2229337	total: 134ms	remaining: 1.78s
# 14:	learn: 453.4342608	total: 135ms	remaining: 1.67s
# 15:	learn: 435.9268855	total: 136ms	remaining: 1.57s
# 16:	learn: 421.6534000	total: 137ms	remaining: 1.48s
# 17:	learn: 410.2618568	total: 138ms	remaining: 1.4s
# 18:	learn: 395.1809259	total: 140ms	remaining: 1.33s
# 19:	learn: 384.5841593	total: 141ms	remaining: 1.27s
# 20:	learn: 374.2717103	total: 142ms	remaining: 1.21s
# 21:	learn: 366.8225708	total: 143ms	remaining: 1.16s
# 22:	learn: 361.7807881	total: 144ms	remaining: 1.11s
# 23:	learn: 355.7847209	total: 145ms	remaining: 1.06s
# 24:	learn: 348.6779492	total: 146ms	remaining: 1.02s
# 25:	learn: 343.2136668	total: 147ms	remaining: 980ms
# 26:	learn: 337.2367028	total: 147ms	remaining: 944ms
# 27:	learn: 333.4028287	total: 149ms	remaining: 916ms
# 28:	learn: 328.3072285	total: 150ms	remaining: 885ms
# 29:	learn: 320.9843267	total: 151ms	remaining: 856ms
# 30:	learn: 314.6826765	total: 152ms	remaining: 828ms
# 31:	learn: 309.2309210	total: 153ms	remaining: 802ms
# 32:	learn: 302.6487362	total: 154ms	remaining: 777ms
# 33:	learn: 298.8677896	total: 155ms	remaining: 756ms
# 34:	learn: 295.1308221	total: 156ms	remaining: 735ms
# 35:	learn: 290.7416280	total: 157ms	remaining: 715ms
# 36:	learn: 286.4793184	total: 158ms	remaining: 695ms
# 37:	learn: 281.6448142	total: 159ms	remaining: 676ms
# 38:	learn: 279.0875597	total: 159ms	remaining: 658ms
# 39:	learn: 275.0590496	total: 160ms	remaining: 641ms
# 40:	learn: 271.2304667	total: 161ms	remaining: 625ms
# 41:	learn: 267.4852419	total: 163ms	remaining: 614ms
# 42:	learn: 262.5538041	total: 164ms	remaining: 600ms
# 43:	learn: 260.1858247	total: 165ms	remaining: 585ms
# 44:	learn: 257.0880372	total: 166ms	remaining: 571ms
# 45:	learn: 253.2548100	total: 167ms	remaining: 558ms
# 46:	learn: 249.8743528	total: 168ms	remaining: 546ms
# 47:	learn: 246.5705528	total: 168ms	remaining: 534ms
# 48:	learn: 243.2532990	total: 169ms	remaining: 522ms
# 49:	learn: 240.1135931	total: 170ms	remaining: 510ms
# 50:	learn: 236.6712413	total: 171ms	remaining: 500ms
# 51:	learn: 234.5480437	total: 172ms	remaining: 490ms
# 52:	learn: 231.8747818	total: 173ms	remaining: 479ms
# 53:	learn: 229.5366120	total: 174ms	remaining: 470ms
# 54:	learn: 226.4002027	total: 175ms	remaining: 460ms
# 55:	learn: 224.1371316	total: 175ms	remaining: 451ms
# 56:	learn: 222.8548059	total: 176ms	remaining: 442ms
# 57:	learn: 220.1641011	total: 178ms	remaining: 435ms
# 58:	learn: 218.5060717	total: 179ms	remaining: 428ms
# 59:	learn: 216.1578591	total: 180ms	remaining: 421ms
# 60:	learn: 215.1181676	total: 181ms	remaining: 413ms
# 61:	learn: 213.4547964	total: 182ms	remaining: 405ms
# 62:	learn: 210.5302034	total: 183ms	remaining: 398ms
# 63:	learn: 208.9575717	total: 184ms	remaining: 390ms
# 64:	learn: 207.1898383	total: 185ms	remaining: 383ms
# 65:	learn: 204.8788040	total: 185ms	remaining: 377ms
# 66:	learn: 201.1255587	total: 186ms	remaining: 370ms
# 67:	learn: 198.2473709	total: 187ms	remaining: 363ms
# 68:	learn: 195.2476377	total: 188ms	remaining: 357ms
# 69:	learn: 194.0793825	total: 189ms	remaining: 351ms
# 70:	learn: 192.5287513	total: 190ms	remaining: 345ms
# 71:	learn: 190.5123017	total: 191ms	remaining: 340ms
# 72:	learn: 187.8222486	total: 193ms	remaining: 335ms
# 73:	learn: 184.9276523	total: 193ms	remaining: 329ms
# 74:	learn: 182.7781787	total: 194ms	remaining: 324ms
# 75:	learn: 181.2910194	total: 195ms	remaining: 318ms
# 76:	learn: 179.0249416	total: 196ms	remaining: 313ms
# 77:	learn: 176.5338748	total: 197ms	remaining: 308ms
# 78:	learn: 173.7479971	total: 198ms	remaining: 303ms
# 79:	learn: 172.9468267	total: 199ms	remaining: 299ms
# 80:	learn: 171.1152396	total: 200ms	remaining: 294ms
# 81:	learn: 170.3848793	total: 201ms	remaining: 289ms
# 82:	learn: 168.4072315	total: 202ms	remaining: 284ms
# 83:	learn: 167.8185194	total: 202ms	remaining: 280ms
# 84:	learn: 165.4782650	total: 203ms	remaining: 275ms
# 85:	learn: 163.8667909	total: 204ms	remaining: 270ms
# 86:	learn: 162.5482848	total: 205ms	remaining: 266ms
# 87:	learn: 160.8259746	total: 206ms	remaining: 263ms
# 88:	learn: 160.3392576	total: 207ms	remaining: 259ms
# 89:	learn: 159.9413551	total: 208ms	remaining: 255ms
# 90:	learn: 158.5435560	total: 209ms	remaining: 251ms
# 91:	learn: 156.6406627	total: 210ms	remaining: 247ms
# 92:	learn: 154.7526921	total: 211ms	remaining: 243ms
# 93:	learn: 153.0010683	total: 212ms	remaining: 239ms
# 94:	learn: 151.3600009	total: 213ms	remaining: 235ms
# 95:	learn: 149.4493795	total: 213ms	remaining: 231ms
# 96:	learn: 148.2745248	total: 214ms	remaining: 227ms
# 97:	learn: 146.8716333	total: 215ms	remaining: 224ms
# 98:	learn: 145.7167585	total: 216ms	remaining: 220ms
# 99:	learn: 144.1627027	total: 217ms	remaining: 217ms
# 100:	learn: 142.6997875	total: 218ms	remaining: 213ms
# 101:	learn: 142.2118566	total: 218ms	remaining: 210ms
# 102:	learn: 140.8807843	total: 219ms	remaining: 206ms
# 103:	learn: 139.0466683	total: 220ms	remaining: 203ms
# 104:	learn: 137.1709857	total: 222ms	remaining: 201ms
# 105:	learn: 136.2859668	total: 223ms	remaining: 198ms
# 106:	learn: 135.9409651	total: 224ms	remaining: 194ms
# 107:	learn: 135.5870361	total: 225ms	remaining: 191ms
# 108:	learn: 134.3636138	total: 225ms	remaining: 188ms
# 109:	learn: 133.5097665	total: 226ms	remaining: 185ms
# 110:	learn: 132.4970255	total: 227ms	remaining: 182ms
# 111:	learn: 131.6575058	total: 228ms	remaining: 179ms
# 112:	learn: 130.2875390	total: 229ms	remaining: 176ms
# 113:	learn: 129.7260662	total: 230ms	remaining: 173ms
# 114:	learn: 128.2664237	total: 231ms	remaining: 171ms
# 115:	learn: 127.0089344	total: 232ms	remaining: 168ms
# 116:	learn: 125.4856213	total: 233ms	remaining: 165ms
# 117:	learn: 125.1706256	total: 233ms	remaining: 162ms
# 118:	learn: 123.1061966	total: 234ms	remaining: 160ms
# 119:	learn: 121.9305482	total: 235ms	remaining: 157ms
# 120:	learn: 121.1527023	total: 237ms	remaining: 155ms
# 121:	learn: 120.8819586	total: 238ms	remaining: 152ms
# 122:	learn: 119.6789490	total: 240ms	remaining: 150ms
# 123:	learn: 118.8365690	total: 241ms	remaining: 147ms
# 124:	learn: 117.4231139	total: 241ms	remaining: 145ms
# 125:	learn: 117.0975109	total: 242ms	remaining: 142ms
# 126:	learn: 116.1989664	total: 243ms	remaining: 140ms
# 127:	learn: 115.5038640	total: 244ms	remaining: 137ms
# 128:	learn: 114.6144535	total: 245ms	remaining: 135ms
# 129:	learn: 114.0415432	total: 246ms	remaining: 132ms
# 130:	learn: 113.5131295	total: 246ms	remaining: 130ms
# 131:	learn: 112.3233439	total: 248ms	remaining: 128ms
# 132:	learn: 111.1485266	total: 249ms	remaining: 125ms
# 133:	learn: 110.2768425	total: 250ms	remaining: 123ms
# 134:	learn: 109.4751487	total: 251ms	remaining: 121ms
# 135:	learn: 107.8752243	total: 252ms	remaining: 119ms
# 136:	learn: 107.1248324	total: 253ms	remaining: 116ms
# 137:	learn: 106.8219145	total: 254ms	remaining: 114ms
# 138:	learn: 105.7015276	total: 255ms	remaining: 112ms
# 139:	learn: 104.4997912	total: 256ms	remaining: 110ms
# 140:	learn: 103.7646459	total: 257ms	remaining: 107ms
# 141:	learn: 103.4463051	total: 258ms	remaining: 105ms
# 142:	learn: 102.2209436	total: 259ms	remaining: 103ms
# 143:	learn: 101.9634865	total: 260ms	remaining: 101ms
# 144:	learn: 100.8276150	total: 261ms	remaining: 98.9ms
# 145:	learn: 99.8608684	total: 261ms	remaining: 96.7ms
# 146:	learn: 98.9274454	total: 262ms	remaining: 94.6ms
# 147:	learn: 98.3067376	total: 263ms	remaining: 92.5ms
# 148:	learn: 97.4939331	total: 264ms	remaining: 90.4ms
# 149:	learn: 96.9691160	total: 265ms	remaining: 88.3ms
# 150:	learn: 96.2628331	total: 266ms	remaining: 86.4ms
# 151:	learn: 95.4949079	total: 268ms	remaining: 84.7ms
# 152:	learn: 95.2684897	total: 269ms	remaining: 82.7ms
# 153:	learn: 94.9901225	total: 270ms	remaining: 80.7ms
# 154:	learn: 94.0689276	total: 271ms	remaining: 78.7ms
# 155:	learn: 93.3946693	total: 272ms	remaining: 76.7ms
# 156:	learn: 92.6456707	total: 273ms	remaining: 74.7ms
# 157:	learn: 91.7574799	total: 273ms	remaining: 72.7ms
# 158:	learn: 90.9903493	total: 274ms	remaining: 70.7ms
# 159:	learn: 90.4364970	total: 275ms	remaining: 68.8ms
# 160:	learn: 89.8043688	total: 276ms	remaining: 66.9ms
# 161:	learn: 89.2035657	total: 277ms	remaining: 64.9ms
# 162:	learn: 88.6267082	total: 278ms	remaining: 63ms
# 163:	learn: 87.7070521	total: 278ms	remaining: 61.1ms
# 164:	learn: 86.8813246	total: 279ms	remaining: 59.2ms
# 165:	learn: 86.2470854	total: 280ms	remaining: 57.4ms
# 166:	learn: 85.7472343	total: 282ms	remaining: 55.6ms
# 167:	learn: 85.3811430	total: 283ms	remaining: 53.8ms
# 168:	learn: 84.8460025	total: 283ms	remaining: 52ms
# 169:	learn: 84.4095145	total: 284ms	remaining: 50.2ms
# 170:	learn: 83.6717752	total: 285ms	remaining: 48.4ms
# 171:	learn: 83.4695555	total: 286ms	remaining: 46.5ms
# 172:	learn: 83.1946086	total: 287ms	remaining: 44.8ms
# 173:	learn: 82.4979014	total: 288ms	remaining: 43ms
# 174:	learn: 81.7702845	total: 288ms	remaining: 41.2ms
# 175:	learn: 81.4272204	total: 289ms	remaining: 39.4ms
# 176:	learn: 81.0559727	total: 290ms	remaining: 37.7ms
# 177:	learn: 80.5710378	total: 291ms	remaining: 36ms
# 178:	learn: 80.1173123	total: 292ms	remaining: 34.2ms
# 179:	learn: 79.3607134	total: 293ms	remaining: 32.5ms
# 180:	learn: 78.9454132	total: 294ms	remaining: 30.8ms
# 181:	learn: 78.0246045	total: 294ms	remaining: 29.1ms
# 182:	learn: 77.6278835	total: 295ms	remaining: 27.4ms
# 183:	learn: 76.6800566	total: 298ms	remaining: 25.9ms
# 184:	learn: 76.2629530	total: 299ms	remaining: 24.2ms
# 185:	learn: 75.8970734	total: 300ms	remaining: 22.6ms
# 186:	learn: 75.5663073	total: 301ms	remaining: 20.9ms
# 187:	learn: 74.7807368	total: 302ms	remaining: 19.3ms
# 188:	learn: 74.3651515	total: 303ms	remaining: 17.6ms
# 189:	learn: 73.8915313	total: 303ms	remaining: 16ms
# 190:	learn: 73.1901889	total: 304ms	remaining: 14.3ms
# 191:	learn: 72.6608964	total: 305ms	remaining: 12.7ms
# 192:	learn: 72.3784081	total: 306ms	remaining: 11.1ms
# 193:	learn: 71.7961363	total: 307ms	remaining: 9.49ms
# 194:	learn: 71.2879661	total: 308ms	remaining: 7.89ms
# 195:	learn: 70.6824638	total: 308ms	remaining: 6.29ms
# 196:	learn: 70.2854300	total: 309ms	remaining: 4.71ms
# 197:	learn: 69.7270874	total: 311ms	remaining: 3.14ms
# 198:	learn: 69.0690493	total: 312ms	remaining: 1.57ms
# 199:	learn: 68.5367295	total: 313ms	remaining: 0us

# %%
predicted = model.predict(X_test)
predicted = np.maximum(predicted, 0)

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(16, 8)) 

plt.plot(
    df['Fecha'],
    df['Accesos'],
    label='Datos Reales (Observados)',
    color='#1f77b4',
    linewidth=2.5,
    alpha=0.8
)

plt.plot(
    df['Fecha'].loc[X_test.index],
    predicted,
    label='Predicción (Test)',
    color='#d62728',
    linestyle='--',
    linewidth=2.5,
    marker='o',
    markersize=5,
    alpha=0.9
)

plt.xlabel('Fecha', fontsize=14, labelpad=10)
plt.ylabel('Número de Accesos', fontsize=14, labelpad=10)
plt.title(
    'Rendimiento del Modelo: Predicciones vs. Valores Reales',
    fontsize=18,
    fontweight='bold',
    pad=20
)

plt.xticks(rotation=45, ha='right', fontsize=11)
plt.yticks(fontsize=11)

# Leyenda y Rejilla
plt.legend(loc='upper left', fontsize=12, frameon=True, shadow=True)
plt.grid(True, axis='both', linestyle='-', alpha=0.5)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

mse = mean_squared_error(y_test, predicted)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print("\nMétricas de Rendimiento del Modelo")
print(f"R² (Coeficiente de Determinación): {r2:.2f}")
print(f"Error Cuadrático Medio (MSE): {mse:.2f}")
print(f"Error Cuadrático Medio Raíz (RMSE): {rmse:.2f}")
print(f"Error Absoluto Medio (MAE): {mae:.2f}")
# Out:
# Métricas de Rendimiento del Modelo
# R² (Coeficiente de Determinación): 0.89
# Error Cuadrático Medio (MSE): 248894.96
# Error Cuadrático Medio Raíz (RMSE): 498.89
# Error Absoluto Medio (MAE): 309.33

# %%
results_df = pd.DataFrame({
    'Índice': X_test.index,
    'Real': y_test,
    'Predicción': predicted
}).sort_values(by='Índice')

plt.figure(figsize=(12, 6))
plt.plot(results_df['Índice'], results_df['Real'], label='Real', color='blue', linewidth=2)
plt.plot(results_df['Índice'], results_df['Predicción'], label='Predicción', color='green', linestyle='--', linewidth=2)
plt.title('Resultados de Predicción', fontsize=14)
plt.xlabel('Índice', fontsize=12)
plt.ylabel('Número de Accesos', fontsize=12)
plt.xticks(rotation=45)
plt.legend(fontsize=10)
plt.grid(alpha=0.5)
plt.tight_layout()
plt.show()
